# %%
import requests

r = requests.get("https://medium.com/devops-dev/top-10-advanced-sql-queries-dd5717b7e902")
print (r.text)
# Out:
# <!doctype html><html lang="en"><head><title data-rh="true">Top 10 Advanced SQL Queries. SQL (Structured Query Language) is a… | by SQL Fundamentals | DevOps.dev</title><meta data-rh="true" charset="utf-8"/><meta data-rh="true" name="viewport" content="width=device-width,minimum-scale=1,initial-scale=1,maximum-scale=1"/><meta data-rh="true" name="theme-color" content="#000000"/><meta data-rh="true" name="twitter:app:name:iphone" content="Medium"/><meta data-rh="true" name="twitter:app:id:iphone" content="828256236"/><meta data-rh="true" property="al:ios:app_name" content="Medium"/><meta data-rh="true" property="al:ios:app_store_id" content="828256236"/><meta data-rh="true" property="al:android:package" content="com.medium.reader"/><meta data-rh="true" property="fb:app_id" content="542599432471018"/><meta data-rh="true" property="og:site_name" content="Medium"/><meta data-rh="true" property="og:type" content="article"/><meta data-rh="true" property="article:published_time" content="202
# ...

# %%
import requests
from bs4 import BeautifulSoup

# Function to get HTML content from a URL or file
def get_html_content(url_or_file):
    try:
        response = requests.get(url_or_file)
        response.raise_for_status()
        return response.text
    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")
        return None

# Replace 'your_file_or_url.html' with your actual HTML file or URL
html_content = get_html_content('https://medium.com/devops-dev/top-10-advanced-sql-queries-dd5717b7e902')

# Parse HTML content with BeautifulSoup
if html_content:
    soup = BeautifulSoup(html_content, 'html.parser')

    # Example: Extracting all links (a tags) from the HTML
    links = soup.find_all('a')
    
    # Display the extracted links
    for link in links:
        print(link.get('href'))
# Out:
# https://rsci.app.link/?%24canonical_url=https%3A%2F%2Fmedium.com%2Fp%2Fdd5717b7e902&%7Efeature=LoOpenInAppButton&%7Echannel=ShowPostUnderCollection&source=---two_column_layout_nav----------------------------------
# https://medium.com/m/signin?operation=register&redirect=https%3A%2F%2Fblog.devops.dev%2Ftop-10-advanced-sql-queries-dd5717b7e902&source=post_page---two_column_layout_nav-----------------------global_nav-----------
# https://medium.com/m/signin?operation=login&redirect=https%3A%2F%2Fblog.devops.dev%2Ftop-10-advanced-sql-queries-dd5717b7e902&source=post_page---two_column_layout_nav-----------------------global_nav-----------
# https://medium.com/?source=---two_column_layout_nav----------------------------------
# https://medium.com/m/signin?operation=register&redirect=https%3A%2F%2Fmedium.com%2Fnew-story&source=---two_column_layout_nav-----------------------new_post_topnav-----------
# ...

# %%
pip install requests beautifulsoup4 requests-html
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from urllib.parse import urlparse
import numpy as np
from requests_html import HTMLSession

# %%
def parse_elements(url,element):
    session = HTMLSession()
    r = session.get(url)
    elements = r.html.find(element)
    return elements

# %%
url='https://medium.com/devops-dev/top-10-advanced-sql-queries-dd5717b7e902'

# %%
paragraphs = parse_elements(url, 'p')
links = parse_elements(url, 'a')

# %%
(paragraphs[20]).attrs
# Out:
# {'class': ('be',
#   'b',
#   'bf',
#   'z',
#   'jk',
#   'jl',
#   'jm',
#   'jn',
#   'jo',
#   'jp',
#   'jq',
#   'jr',
#   'bj')}

# %%
(links[10]).attrs['href']
# Out:
# 'https://medium.com/@sqlfundamentals?source=post_page-----dd5717b7e902--------------------------------'

# %%
for p in paragraphs:
  print(p.text)
# Out:
# Sign up
# Sign in
# Sign up
# Sign in
# Member-only story
# SQL Fundamentals
# Follow
# DevOps.dev
# --
# 4
# Share
# SQL (Structured Query Language) is a versatile tool for managing and querying data in relational databases. While basic SQL queries are essential, advanced SQL queries take your data manipulation and analysis skills to the next level. In this guide, we’ll explore the top 10 advanced SQL queries with practical code examples.
# Query: Retrieve all employees and their managers in a hierarchical structure using a recursive CTE.
# Query: Pivot the sales table to display product categories as columns and the total sales for each month.
# Query: Calculate the running total of sales by order date.
# Query: Rank employees by their salary within each department.
# Query: Identify missing order numbers in a sequence.
# --
# --
# 4
# DevOps.dev
# Learn SQL with new contents every day
# Help
# Status
# About
# Careers
# Blog
# Privacy
# Terms
# Text to speech
# Teams

# %%
for a in links:
  print(a.text)
# Out:
# Open in app
# Sign up
# Sign in
#
# Write
#
# Sign up
# Sign in
#
#
# SQL Fundamentals
# Follow
# DevOps.dev
#
#
# Pexels
#
#
#
#
#
# Follow
#
# Written by SQL Fundamentals
# 1.7K Followers
# DevOps.dev
# Follow
#
# Help
# Status
# About
# Careers
# Blog
# Privacy
# Terms
# Text to speech
# Teams

# %%
points = parse_elements(url, 'li')

# %%
for point in points:
  print(point.text)

# %%
def get_and_parse(url):
  response = requests.get(url)

# Parse the HTML content with Beautiful Soup
  soup = BeautifulSoup(response.content, 'html.parser')

# Remove unwanted elements (script, style, comments, etc.)
  for element in soup(['script', 'style', 'comment']):
      element.extract()

# Extract the visible text
  text = soup.get_text(separator=' ')
  return text

# %%
def parse_elements(url,element):
    session = HTMLSession()
    r = session.get(url)
    elements = r.html.find(element)
    return elements

# %%
def sentiment_detection(sentence):
    positive_words = ('happy', 'sunny', 'positive', 'triumphant', 'optimistic', 'wonderful', 'significant', 'achieve','capabilities','progress','prized')
    negative_words = ('sad', 'terrible', 'frightening', 'rainy', 'scary', 'shocked', 'critical','bottlenecked')

    positive = any(sentence.count(i) > 0 for i in positive_words)
    negative = any(sentence.count(i) > 0 for i in negative_words)

    if positive == negative == False:
        return "neutral"
    elif positive != negative:
        return "positive" if positive else "negative"
    else:
        return "mixed"

# %%
def topic_detection(sentence):
    database_words = ('Database', 'Data-model', 'library', 'Pivot', 'Recursion','','Queries')
    SQL_words = ('SQL', 'DB2', 'Oracle', 'PostgreSQl', 'Mysql', 'DML','Database administrator')
    datawords = ('Database', 'Data-dictonary','Recursion','Data-model','Query')
    database = any(sentence.count(i) > 0 for i in database_words)
    SQL = any(sentence.count(i) > 0 for i in SQL_words)
    data= any(sentence.count(i) > 0 for i in datawords)
    topics = []
    if database == True:
        topics.append(" Database")
    if SQL == True:
        topics.append("SQL")
    if data == True:
        topics.append("Data")
    return topics

# %%
url = 'https://medium.com/devops-dev/top-10-advanced-sql-queries-dd5717b7e902'
paragraphs = parse_elements(url, 'p')
links = parse_elements(url, 'a')

# %%
(paragraphs)
# Out:
# [<Element 'p' class=('be', 'b', 'dw', 'dx', 'dy', 'dz', 'ea', 'eb', 'ec', 'ed', 'ee', 'ef', 'dt')>,
#  <Element 'p' class=('be', 'b', 'dw', 'dx', 'dy', 'dz', 'ea', 'eb', 'ec', 'ed', 'ee', 'ef', 'dt')>,
#  <Element 'p' class=('be', 'b', 'dw', 'dx', 'dy', 'dz', 'ea', 'eb', 'ec', 'ed', 'ee', 'ef', 'dt')>,
#  <Element 'p' class=('be', 'b', 'dw', 'dx', 'dy', 'dz', 'ea', 'eb', 'ec', 'ed', 'ee', 'ef', 'dt')>,
#  <Element 'p' class=('be', 'b', 'bf', 'z', 'dt')>,
#  <Element 'p' class=('be', 'b', 'iu', 'iv', 'bj')>,
#  <Element 'p' class=('be', 'b', 'iu', 'iv', 'dt')>,
#  <Element 'p' class=('be', 'b', 'bf', 'z', 'jk', 'jl', 'jm', 'jn', 'jo', 'jp', 'jq', 'jr', 'bj')>,
#  <Element 'p' class=('be', 'b', 'du', 'z', 'dt')>,
#  <Element 'p' class=('be', 'b', 'du', 'z', 'dt')>,
#  <Element 'p' class=('be', 'b', 'bf', 'z', 'dt')>,
# ...

# %%
p_dictionary = {}
p_list = []
topic_list = []
for p in range(0, len(paragraphs)):
      if len(paragraphs[p].text) > 10:
          p_list.append(paragraphs[p].text)
          topic_list.append(topic_detection(paragraphs[p].text))
p_dictionary['Paragraphs'] = p_list
p_dictionary['Topics'] = topic_list

# %%
p_dictionary['Topics']
# Out:
# [[' Database'],
#  [' Database', 'SQL'],
#  [' Database', 'SQL', 'Data'],
#  [' Database', 'Data'],
#  [' Database', 'Data'],
#  [' Database', 'Data'],
#  [' Database', 'Data'],
#  [' Database', 'Data'],
#  [' Database', 'SQL'],
#  [' Database']]

# %%
df = pd.DataFrame(p_dictionary)

# %%
print(df.head())
# Out:
#                                           Paragraphs                  Topics
# 0                                  Member-only story             [ Database]
# 1                                   SQL Fundamentals        [ Database, SQL]
# 2  SQL (Structured Query Language) is a versatile...  [ Database, SQL, Data]
# 3  Query: Retrieve all employees and their manage...       [ Database, Data]
# 4  Query: Pivot the sales table to display produc...       [ Database, Data]

# %%
medium_df = pd.DataFrame(p_dictionary)

# %%
medium_df.head(9)
# Out:
#                                           Paragraphs                  Topics
# 0                                  Member-only story             [ Database]
# 1                                   SQL Fundamentals        [ Database, SQL]
# 2  SQL (Structured Query Language) is a versatile...  [ Database, SQL, Data]
# 3  Query: Retrieve all employees and their manage...       [ Database, Data]
# 4  Query: Pivot the sales table to display produc...       [ Database, Data]
# 5  Query: Calculate the running total of sales by...       [ Database, Data]
# 6  Query: Rank employees by their salary within e...       [ Database, Data]
# 7  Query: Identify missing order numbers in a seq...       [ Database, Data]
# 8              Learn SQL with new contents every day        [ Database, SQL]

# %%
medium_df2 = pd.DataFrame({'Paragraph_Elements':paragraphs})

# %%
medium_df2.head()
# Out:
#                                   Paragraph_Elements
# 0  <Element 'p' class=('be', 'b', 'dw', 'dx', 'dy...
# 1  <Element 'p' class=('be', 'b', 'dw', 'dx', 'dy...
# 2  <Element 'p' class=('be', 'b', 'dw', 'dx', 'dy...
# 3  <Element 'p' class=('be', 'b', 'dw', 'dx', 'dy...
# 4   <Element 'p' class=('be', 'b', 'bf', 'z', 'dt')>

# %%
medium_df['Character Count'] = medium_df['Paragraphs'].apply(lambda x: len(x))

# %%
medium_df.head(10)
# Out:
#                                           Paragraphs                  Topics  \
# 0                                  Member-only story             [ Database]
# 1                                   SQL Fundamentals        [ Database, SQL]
# 2  SQL (Structured Query Language) is a versatile...  [ Database, SQL, Data]
# 3  Query: Retrieve all employees and their manage...       [ Database, Data]
# 4  Query: Pivot the sales table to display produc...       [ Database, Data]
# 5  Query: Calculate the running total of sales by...       [ Database, Data]
# 6  Query: Rank employees by their salary within e...       [ Database, Data]
# 7  Query: Identify missing order numbers in a seq...       [ Database, Data]
# 8              Learn SQL with new contents every day        [ Database, SQL]
# 9                                     Text to speech             [ Database]
#
#    Character Count
# 0               17
# 1               16
# 2              325
# 3               99
# 4              105
# ...

# %%
medium_df['Topic Count'] = medium_df['Topics'].apply(len)
medium_df.head()
# Out:
#                                           Paragraphs                  Topics  \
# 0                                  Member-only story             [ Database]
# 1                                   SQL Fundamentals        [ Database, SQL]
# 2  SQL (Structured Query Language) is a versatile...  [ Database, SQL, Data]
# 3  Query: Retrieve all employees and their manage...       [ Database, Data]
# 4  Query: Pivot the sales table to display produc...       [ Database, Data]
#
#    Character Count  Topic Count
# 0               17            1
# 1               16            2
# 2              325            3
# 3               99            2
# 4              105            2

# %%
medium_df['Sentiment'] = medium_df['Paragraphs'].apply(sentiment_detection)

# %%
medium_df.head(10)
# Out:
#                                           Paragraphs                  Topics  \
# 0                                  Member-only story             [ Database]
# 1                                   SQL Fundamentals        [ Database, SQL]
# 2  SQL (Structured Query Language) is a versatile...  [ Database, SQL, Data]
# 3  Query: Retrieve all employees and their manage...       [ Database, Data]
# 4  Query: Pivot the sales table to display produc...       [ Database, Data]
# 5  Query: Calculate the running total of sales by...       [ Database, Data]
# 6  Query: Rank employees by their salary within e...       [ Database, Data]
# 7  Query: Identify missing order numbers in a seq...       [ Database, Data]
# 8              Learn SQL with new contents every day        [ Database, SQL]
# 9                                     Text to speech             [ Database]
#
#    Character Count  Topic Count Sentiment
# 0               17            1   neutral
# ...

# %%
category_amount = medium_df['Sentiment'].value_counts()
print(category_amount)
print(list(category_amount))
print(list(category_amount.keys()))
# Out:
# Sentiment
# neutral    10
# Name: count, dtype: int64
# [10]
# ['neutral']

# %%
medium_df['SQL'] = np.where('AI' in medium_df['Topics'][0], 1, 0)

# %%
medium_df.head(9)
# Out:
#                                           Paragraphs                  Topics  \
# 0                                  Member-only story             [ Database]
# 1                                   SQL Fundamentals        [ Database, SQL]
# 2  SQL (Structured Query Language) is a versatile...  [ Database, SQL, Data]
# 3  Query: Retrieve all employees and their manage...       [ Database, Data]
# 4  Query: Pivot the sales table to display produc...       [ Database, Data]
# 5  Query: Calculate the running total of sales by...       [ Database, Data]
# 6  Query: Rank employees by their salary within e...       [ Database, Data]
# 7  Query: Identify missing order numbers in a seq...       [ Database, Data]
# 8              Learn SQL with new contents every day        [ Database, SQL]
#
#    Character Count  Topic Count Sentiment  AI  SQL
# 0               17            1   neutral   0    0
# 1               16            2   neutral   0    0
# ...

# %%
medium_df['Data'] = np.where('data' in medium_df['Topics'], 1, 0)

# %%
'data' in [['data','ai'],1]
# Out:
# False

# %%
medium_df['Topics']
# Out:
# 0               [ Database]
# 1          [ Database, SQL]
# 2    [ Database, SQL, Data]
# 3         [ Database, Data]
# 4         [ Database, Data]
# 5         [ Database, Data]
# 6         [ Database, Data]
# 7         [ Database, Data]
# 8          [ Database, SQL]
# 9               [ Database]
# Name: Topics, dtype: object

# %%
medium_df.head(9)
# Out:
#                                           Paragraphs                  Topics  \
# 0                                  Member-only story             [ Database]
# 1                                   SQL Fundamentals        [ Database, SQL]
# 2  SQL (Structured Query Language) is a versatile...  [ Database, SQL, Data]
# 3  Query: Retrieve all employees and their manage...       [ Database, Data]
# 4  Query: Pivot the sales table to display produc...       [ Database, Data]
# 5  Query: Calculate the running total of sales by...       [ Database, Data]
# 6  Query: Rank employees by their salary within e...       [ Database, Data]
# 7  Query: Identify missing order numbers in a seq...       [ Database, Data]
# 8              Learn SQL with new contents every day        [ Database, SQL]
#
#    Character Count  Topic Count Sentiment  AI  SQL  Data
# 0               17            1   neutral   0    0     0
# 1               16            2   neutral   0    0     0
# ...

# %%
medium_df['Data'] = medium_df['Topics'].apply(lambda x:1 if 'data' in x else 0)

# %%
medium_df['SQL'] = medium_df['Topics'].apply(lambda x:1 if 'SQL' in x else 0)

# %%
medium_df.head(9)
# Out:
#                                           Paragraphs                  Topics  \
# 0                                  Member-only story             [ Database]
# 1                                   SQL Fundamentals        [ Database, SQL]
# 2  SQL (Structured Query Language) is a versatile...  [ Database, SQL, Data]
# 3  Query: Retrieve all employees and their manage...       [ Database, Data]
# 4  Query: Pivot the sales table to display produc...       [ Database, Data]
# 5  Query: Calculate the running total of sales by...       [ Database, Data]
# 6  Query: Rank employees by their salary within e...       [ Database, Data]
# 7  Query: Identify missing order numbers in a seq...       [ Database, Data]
# 8              Learn SQL with new contents every day        [ Database, SQL]
#
#    Character Count  Topic Count Sentiment  AI  SQL  Data
# 0               17            1   neutral   0    0     0
# 1               16            2   neutral   0    1     0
# ...

# %%
import matplotlib.pyplot as plt



# Extract category names and corresponding amounts
#categories = list(category_amount.keys())
#amounts = list(category_amount.values())

# Plotting the bar graph
plt.hist(list(category_amount.keys()), list(category_amount))

# Customize the plot
plt.xlabel('Topics')
plt.ylabel('Total topics')
plt.title('Total count topics')
#plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
topic_counts = [medium_df['SQL'].sum(), medium_df['Data'].sum()]
topic_labels = ['SQL', 'data']

# %%
# Plotting the bar graph
plt.bar(topic_labels, topic_counts)

# Customize the plot
plt.xlabel('Topics')
plt.ylabel('Total Count')
plt.title('Total count of topics')
plt.xticks(rotation=45)

# Show the plot
plt.show()
